# %% [markdown]
# # Running NoahSims
#
# This notebook serves as the ipython notebook version of deploying the 'runnoahsims.py' file for easier visualization and segmenting purposes.
#
# Much of the documentation and programming is the same.

# %% [markdown]
# # Minor thing to note
#
# Currently in  path/Simulation/Notebooks/NoahSim
#
# Relevant python files are in path/Simulation/BurstCube/NoahSim

# %%
from NoahCube import Sky, BurstCube

# %%
NSIDE = 4 
STRENGTH = 500
BACKGROUND = 1000
TILT = 15
ALTERNATING = 75
TEST = False
TALK = True
plot = True
# %matplotlib inline

"""
Parameters
----------

NSIDE : int
	A power of 2, corresponding to the number of pixels to occupy TSM (ie NSIDE = 8 => 768 pixels, etc.)

STRENGTH : float
	The desired strength of the incident GRBs. 

BACKGROUND : float 
	The desired background in the detectors. 


TILT : float
	Angle in degrees to bend the detectors. Optimal range is somewhere between 30 and 45 degrees. 

ALTERNATING : bool
	Condition on whether or not you want to alternate the tilt pattern of the detectors. 

TEST : bool
	Condition on whether or not you are testing over the entire sky, or just one for testing purposes. 

TALK : bool  
	Condition on whether or not you want simulation to tell you the sky localization for every point, as it is running. 
"""

# %% [markdown]
# # Another note
#
# This model is built with the response of the GRB detectors at .76, a result found preliminarily while using a MEGAlib simulation of just the detector.
#
# To update this, please refer to the burstutils.py file, and toy around with the "lookupA,etc." functions.

# %%
sim = Sky(NSIDE,STRENGTH)

#run this file, and you immediately get

#run this file, and you immediately get
testcube = BurstCube(BACKGROUND,TILT,alternating =ALTERNATING)
_ = testcube.initialize #supress output for now, but it is now a property so we chilling. 


offsets , errors = testcube.response2GRB(sim,talk=TALK,test = TEST)


if plot:
#Only difference is the graphs are opened in the notebook, as opposed to saved. 
    from healpy import newvisufunc
    import matplotlib.pyplot as plt
    newvisufunc.mollview(offsets,min=0, max=20,unit='Localization Accurary (degrees)',graticule=True,graticule_labels=True)
    if type(ALTERNATING) == int:
        plt.title('All Sky Localization Accuracy for BurstCube with Orientation ' + str(TILT) +' by '+str(ALTERNATING) +' deg' )  #should add something about design too! 
    #plt.savefig('offset'+'tilt'+str(TILT)+'s'+str(STRENGTH)+'bg'+str(BACKGROUND)+'.png')
    else:
        plt.title('All Sky Localization Accuracy for BurstCube with Orientation ' + str(TILT) + ' deg' )  #should add something about design too! 

    plt.figure()
    newvisufunc.mollview(errors,min=0, max=60,unit='Localization Error (degrees)',graticule=True,graticule_labels=True)
    
    if type(ALTERNATING) == int:
        plt.title('All Sky Localization Error for BurstCube with Orientation ' + str(TILT) +' by '+str(ALTERNATING) +' deg' )  #should add something about design too! 
    #plt.savefig('error'+'tilt'+str(TILT)+'s'+str(STRENGTH)+'bg'+str(BACKGROUND)+'.png')
    else:
        plt.title('All Sky Localization Error for BurstCube with Orientation ' + str(TILT) + ' deg' )
# Out:
# Detector Class: 15.0 by 75.0degrees
# For bursts @ [ 11.71585239  45.        ]
# Avg offset: 13.4669307624
# Std. Error: 13.8517716721
#
# For bursts @ [  11.71585239  135.        ]
# Avg offset: 12.5470732233
# Std. Error: 13.7043397385
#
# For bursts @ [  11.71585239  225.        ]
# Avg offset: 10.3588554824
# Std. Error: 12.7555132289
#
# For bursts @ [  11.71585239  315.        ]
# Avg offset: 12.7595163477
# Std. Error: 18.3506186237
#
# For bursts @ [ 23.55646431  22.5       ]
# Avg offset: 11.4944739204
# Std. Error: 25.7705195923
#
# For bursts @ [ 23.55646431  67.5       ]
# Avg offset: 20.9596749183
# Std. Error: 21.6696374513
#
# For bursts @ [  23.55646431  112.5       ]
# Avg offset: 25.491335191
# Std. Error: 18.5413897874
#
# For bursts @ [  23.55646431  157.5       ]
# Avg offset: 13.6714162478
# Std. Error: 29.6939902936
#
# For bursts @ [  23.55646431  202.5       ]
# Avg offset: 10.1450736818
# Std. Error: 23.6534598491
#
# For bursts @ [  23.55646431  247.5       ]
# Avg offset: 21.5965457741
# Std. Error: 18.9800312049
#
# For bursts @ [  23.55646431  292.5       ]
# Avg offset: 26.394970184
# Std. Error: 16.9906427684
#
# For bursts @ [  23.55646431  337.5       ]
# Avg offset: 11.1499586389
# Std. Error: 26.1381116417
#
# For bursts @ [ 35.6590877  15.       ]
# Avg offset: 12.3176300598
# Std. Error: 27.5406765712
#
# For bursts @ [ 35.6590877  45.       ]
# Avg offset: 26.2992277238
# Std. Error: 20.6202454349
#
# For bursts @ [ 35.6590877  75.       ]
# Avg offset: 31.9141049655
# Std. Error: 19.0410107684
#
# For bursts @ [  35.6590877  105.       ]
# Avg offset: 34.1275132746
# Std. Error: 16.3842247375
#
# For bursts @ [  35.6590877  135.       ]
# Avg offset: 28.2252889248
# Std. Error: 19.0311398065
#
# For bursts @ [  35.6590877  165.       ]
# Avg offset: 15.2716811922
# Std. Error: 30.8659662369
#
# For bursts @ [  35.6590877  195.       ]
# Avg offset: 11.5114047505
# Std. Error: 26.2056587164
#
# For bursts @ [  35.6590877  225.       ]
# Avg offset: 26.8514949925
# Std. Error: 25.2039778495
#
# For bursts @ [  35.6590877  255.       ]
# Avg offset: 30.7548802421
# Std. Error: 19.1905246991
#
# For bursts @ [  35.6590877  285.       ]
# Avg offset: 34.4598953573
# Std. Error: 12.4892820781
#
# For bursts @ [  35.6590877  315.       ]
# Avg offset: 29.4294094734
# Std. Error: 20.8781299032
#
# For bursts @ [  35.6590877  345.       ]
# Avg offset: 10.7648349291
# Std. Error: 34.4841579316
#
# For bursts @ [ 48.1896851  11.25     ]
# Avg offset: 10.6404012644
# Std. Error: 41.6512709855
#
# For bursts @ [ 48.1896851  33.75     ]
# Avg offset: 27.3843059907
# Std. Error: 36.0519398274
#
# For bursts @ [ 48.1896851  56.25     ]
# Avg offset: 37.2838868787
# Std. Error: 29.3382467865
#
# For bursts @ [ 48.1896851  78.75     ]
# Avg offset: 41.9432878282
# Std. Error: 17.9615587964
#
# For bursts @ [  48.1896851  101.25     ]
# Avg offset: 44.2622922712
# Std. Error: 14.4040264642
#
# For bursts @ [  48.1896851  123.75     ]
# Avg offset: 36.5552865734
# Std. Error: 26.7521529676
#
# For bursts @ [  48.1896851  146.25     ]
# Avg offset: 29.8456712048
# Std. Error: 29.1223699169
#
# For bursts @ [  48.1896851  168.75     ]
# Avg offset: 10.2318708046
# Std. Error: 44.3627937445
#
# For bursts @ [  48.1896851  191.25     ]
# Avg offset: 9.81338489875
# Std. Error: 41.2166450817
#
# For bursts @ [  48.1896851  213.75     ]
# Avg offset: 33.0392225701
# Std. Error: 31.0426565595
#
# For bursts @ [  48.1896851  236.25     ]
# Avg offset: 35.7716483336
# Std. Error: 30.583544177
#
# For bursts @ [  48.1896851  258.75     ]
# Avg offset: 44.7705079211
# Std. Error: 17.5558107995
#
# For bursts @ [  48.1896851  281.25     ]
# Avg offset: 47.2955762549
# Std. Error: 16.4627825368
#
# For bursts @ [  48.1896851  303.75     ]
# Avg offset: 37.0516782922
# Std. Error: 26.5056090084
#
# For bursts @ [  48.1896851  326.25     ]
# Avg offset: 26.2007229631
# Std. Error: 33.2642350896
#
# For bursts @ [  48.1896851  348.75     ]
# Avg offset: 8.81308694503
# Std. Error: 50.2428655571
#
# For bursts @ [ 60.   0.]
# Avg offset: 4.49437235845
# Std. Error: 57.3724682205
#
# For bursts @ [ 60.   22.5]
# Avg offset: 26.9275488588
# Std. Error: 44.4247999825
#
# For bursts @ [ 60.  45.]
# Avg offset: 43.5264588058
# Std. Error: 37.7379550109
#
# For bursts @ [ 60.   67.5]
# Avg offset: 52.914141789
# Std. Error: 23.9276499245
#
# For bursts @ [ 60.  90.]
# Avg offset: 57.968000257
# Std. Error: 15.221637165
#
# For bursts @ [  60.   112.5]
# Avg offset: 55.7175269124
# Std. Error: 22.5711169612
#
# For bursts @ [  60.  135.]
# Avg offset: 40.5170716503
# Std. Error: 33.9589824165
#
# For bursts @ [  60.   157.5]
# Avg offset: 24.0394435942
# Std. Error: 49.4117822694
#
# For bursts @ [  60.  180.]
# Avg offset: 5.74766456413
# Std. Error: 56.4091567127
#
# For bursts @ [  60.   202.5]
# Avg offset: 27.1001850865
# Std. Error: 43.8693082279
#
# For bursts @ [  60.  225.]
# Avg offset: 44.1327980929
# Std. Error: 34.6019057547
#
# For bursts @ [  60.   247.5]
# Avg offset: 56.060599208
# Std. Error: 18.3155709756
#
# For bursts @ [  60.  270.]
# Avg offset: 59.2409035561
# Std. Error: 16.5041428627
#
# For bursts @ [  60.   292.5]
# Avg offset: 50.435351995
# Std. Error: 30.0430150054
#
# For bursts @ [  60.  315.]
# Avg offset: 39.8504745617
# Std. Error: 37.8285319185
#
# For bursts @ [  60.   337.5]
# Avg offset: 24.1048118101
# Std. Error: 48.0095256734
#
# For bursts @ [ 70.52877937  11.25      ]
# Avg offset: 17.4837227373
# Std. Error: 60.3889016657
#
# For bursts @ [ 70.52877937  33.75      ]
# Avg offset: 43.018283455
# Std. Error: 44.7318792983
#
# For bursts @ [ 70.52877937  56.25      ]
# Avg offset: 52.2547250533
# Std. Error: 44.8103088961
#
# For bursts @ [ 70.52877937  78.75      ]
# Avg offset: 69.1270313718
# Std. Error: 20.3597054011
#
# For bursts @ [  70.52877937  101.25      ]
# Avg offset: 63.9190253256
# Std. Error: 20.1829095779
#
# For bursts @ [  70.52877937  123.75      ]
# Avg offset: 54.1485746445
# Std. Error: 39.1801282805
#
# For bursts @ [  70.52877937  146.25      ]
# Avg offset: 37.7986445896
# Std. Error: 48.8489612091
#
# For bursts @ [  70.52877937  168.75      ]
# Avg offset: 23.9782271383
# Std. Error: 52.360741346
#
# For bursts @ [  70.52877937  191.25      ]
# Avg offset: 15.5949656546
# Std. Error: 59.8757978472
#
# For bursts @ [  70.52877937  213.75      ]
# Avg offset: 42.5891826874
# Std. Error: 41.88358847
#
# For bursts @ [  70.52877937  236.25      ]
# Avg offset: 56.7176004543
# Std. Error: 33.6326213263
#
# For bursts @ [  70.52877937  258.75      ]
# Avg offset: 64.0907252887
# Std. Error: 25.6887700278
#
# For bursts @ [  70.52877937  281.25      ]
# Avg offset: 67.1048471653
# Std. Error: 26.0715397128
#
# For bursts @ [  70.52877937  303.75      ]
# Avg offset: 54.6085824052
# Std. Error: 37.8115284441
#
# For bursts @ [  70.52877937  326.25      ]
# Avg offset: 35.8045528005
# Std. Error: 52.0292553067
#
# For bursts @ [  70.52877937  348.75      ]
# Avg offset: 18.133604867
# Std. Error: 60.2597519097
#
# For bursts @ [ 80.40593177   0.        ]
# Avg offset: 62.276855232
# Std. Error: 71.3008184134
#
# For bursts @ [ 80.40593177  22.5       ]
# Avg offset: 64.4548103334
# Std. Error: 64.6581174407
#
# For bursts @ [ 80.40593177  45.        ]
# Avg offset: 81.3968182763
# Std. Error: 56.6870341407
#
# For bursts @ [ 80.40593177  67.5       ]
# Avg offset: 64.1830414252
# Std. Error: 48.9066482381
#
# For bursts @ [ 80.40593177  90.        ]
# Avg offset: 78.357813714
# Std. Error: 20.2954999664
#
# For bursts @ [  80.40593177  112.5       ]
# Avg offset: 70.3055275034
# Std. Error: 32.9426953875
#
# For bursts @ [  80.40593177  135.        ]
# Avg offset: 101.594089518
# Std. Error: 53.6569615608
#
# For bursts @ [  80.40593177  157.5       ]
# Avg offset: 58.6273811384
# Std. Error: 59.2364164066
#
# For bursts @ [  80.40593177  180.        ]
# Avg offset: 115.662434207
# Std. Error: 68.8598387211
#
# For bursts @ [  80.40593177  202.5       ]
# Avg offset: 110.726646883
# Std. Error: 62.0043467295
#
# For bursts @ [  80.40593177  225.        ]
# Avg offset: 102.938587071
# Std. Error: 62.1701939344
#
# For bursts @ [  80.40593177  247.5       ]
# Avg offset: 67.4104929882
# Std. Error: 47.6079979365
#
# For bursts @ [  80.40593177  270.        ]
# Avg offset: 74.8273803975
# Std. Error: 23.6266118172
#
# For bursts @ [  80.40593177  292.5       ]
# Avg offset: 75.358510064
# Std. Error: 27.6411984123
#
# For bursts @ [  80.40593177  315.        ]
# Avg offset: 72.2508084447
# Std. Error: 52.5191117765
#
# For bursts @ [  80.40593177  337.5       ]
# Avg offset: 97.3281054756
# Std. Error: 67.9126170176
#
# For bursts @ [ 90.    11.25]
# Avg offset: 87.6857205851
# Std. Error: 67.1372002057
#
# For bursts @ [ 90.    33.75]
# Avg offset: 102.940968987
# Std. Error: 58.3617653571
#
# For bursts @ [ 90.    56.25]
# Avg offset: 95.8933181549
# Std. Error: 58.8745024386
#
# For bursts @ [ 90.    78.75]
# Avg offset: 95.5352957894
# Std. Error: 42.0512848281
#
# For bursts @ [  90.    101.25]
# Avg offset: 88.146285309
# Std. Error: 33.1943670289
#
# For bursts @ [  90.    123.75]
# Avg offset: 101.927018434
# Std. Error: 42.0871541617
#
# For bursts @ [  90.    146.25]
# Avg offset: 111.248436942
# Std. Error: 57.5709416575
#
# For bursts @ [  90.    168.75]
# Avg offset: 103.047866111
# Std. Error: 65.3227860153
#
# For bursts @ [  90.    191.25]
# Avg offset: 108.114974264
# Std. Error: 68.1278472006
#
# For bursts @ [  90.    213.75]
# Avg offset: 116.16820366
# Std. Error: 53.8719910213
#
# For bursts @ [  90.    236.25]
# Avg offset: 95.1949437406
# Std. Error: 49.9214818073
#
# For bursts @ [  90.    258.75]
# Avg offset: 89.985622181
# Std. Error: 33.6760636045
#
# For bursts @ [  90.    281.25]
# Avg offset: 93.1516395159
# Std. Error: 60.5668267636
#
# For bursts @ [  90.    303.75]
# Avg offset: 107.491680289
# Std. Error: 50.467771013
#
# For bursts @ [  90.    326.25]
# Avg offset: 92.6129410541
# Std. Error: 52.2540344709
#
# For bursts @ [  90.    348.75]
# Avg offset: 106.531175654
# Std. Error: 59.7435920992
#
# For bursts @ [ 99.59406823   0.        ]
# Avg offset: 128.54092549
# Std. Error: 49.3268456142
#
# For bursts @ [ 99.59406823  22.5       ]
# Avg offset: 108.944605024
# Std. Error: 55.223766714
#
# For bursts @ [ 99.59406823  45.        ]
# Avg offset: 110.03727747
# Std. Error: 46.4364063689
#
# For bursts @ [ 99.59406823  67.5       ]
# Avg offset: 91.7480365162
# Std. Error: 38.1296702047
#
# For bursts @ [ 99.59406823  90.        ]
# Avg offset: 97.8503501738
# Std. Error: 38.7263707402
#
# For bursts @ [  99.59406823  112.5       ]
# Avg offset: 95.1081453013
# Std. Error: 41.4316934796
#
# For bursts @ [  99.59406823  135.        ]
# Avg offset: 106.939220229
# Std. Error: 39.1892022003
#
# For bursts @ [  99.59406823  157.5       ]
# Avg offset: 131.069756478
# Std. Error: 56.7555909294
#
# For bursts @ [  99.59406823  180.        ]
# Avg offset: 118.233386137
# Std. Error: 48.1081388821
#
# For bursts @ [  99.59406823  202.5       ]
# Avg offset: 131.959904557
# Std. Error: 56.1419436629
#
# For bursts @ [  99.59406823  225.        ]
# Avg offset: 110.551673047
# Std. Error: 50.797092488
#
# For bursts @ [  99.59406823  247.5       ]
# Avg offset: 92.6411079728
# Std. Error: 47.9391818677
#
# For bursts @ [  99.59406823  270.        ]
# Avg offset: 90.8827663284
# Std. Error: 28.5030707715
#
# For bursts @ [  99.59406823  292.5       ]
# Avg offset: 90.7133462638
# Std. Error: 49.6595306346
#
# For bursts @ [  99.59406823  315.        ]
# Avg offset: 89.0217808595
# Std. Error: 34.2151726753
#
# For bursts @ [  99.59406823  337.5       ]
# Avg offset: 118.293872793
# Std. Error: 54.7227641708
#
# For bursts @ [ 109.47122063   11.25      ]
# Avg offset: 123.039178608
# Std. Error: 56.6571494229
#
# For bursts @ [ 109.47122063   33.75      ]
# Avg offset: 97.445580049
# Std. Error: 37.6366189034
#
# For bursts @ [ 109.47122063   56.25      ]
# Avg offset: 99.6051169436
# Std. Error: 43.1033523294
#
# For bursts @ [ 109.47122063   78.75      ]
# Avg offset: 101.766136592
# Std. Error: 40.0639485615
#
# For bursts @ [ 109.47122063  101.25      ]
# Avg offset: 100.242216914
# Std. Error: 44.2483406286
#
# For bursts @ [ 109.47122063  123.75      ]
# Avg offset: 91.8761195623
# Std. Error: 47.2860526275
#
# For bursts @ [ 109.47122063  146.25      ]
# Avg offset: 109.835138176
# Std. Error: 35.4073187732
#
# For bursts @ [ 109.47122063  168.75      ]
# Avg offset: 90.7217172328
# Std. Error: 44.7070105542
#
# For bursts @ [ 109.47122063  191.25      ]
# Avg offset: 115.523177946
# Std. Error: 33.283053671
#
# For bursts @ [ 109.47122063  213.75      ]
# Avg offset: 92.002722384
# Std. Error: 46.4187222615
#
# For bursts @ [ 109.47122063  236.25      ]
# Avg offset: 110.456228086
# Std. Error: 43.7792482454
#
# For bursts @ [ 109.47122063  258.75      ]
# Avg offset: 104.665076641
# Std. Error: 34.423595279
#
# For bursts @ [ 109.47122063  281.25      ]
# Avg offset: 96.683635742
# Std. Error: 45.3435752828
#
# For bursts @ [ 109.47122063  303.75      ]
# Avg offset: 102.067392406
# Std. Error: 34.2917956573
#
# For bursts @ [ 109.47122063  326.25      ]
# Avg offset: 103.408817843
# Std. Error: 35.0315367359
#
# For bursts @ [ 109.47122063  348.75      ]
# Avg offset: 111.220111904
# Std. Error: 42.660739088
#
# For bursts @ [ 120.    0.]
# Avg offset: 139.363998707
# Std. Error: 35.9657976246
#
# For bursts @ [ 120.    22.5]
# Avg offset: 100.152473952
# Std. Error: 50.192602532
#
# For bursts @ [ 120.   45.]
# Avg offset: 92.9780732003
# Std. Error: 46.3194679665
#
# For bursts @ [ 120.    67.5]
# Avg offset: 110.884610209
# Std. Error: 36.981613938
#
# For bursts @ [ 120.   90.]
# Avg offset: 103.60713287
# Std. Error: 45.8290724076
#
# For bursts @ [ 120.   112.5]
# Avg offset: 104.253460004
# Std. Error: 49.6137212445
#
# For bursts @ [ 120.  135.]
# Avg offset: 93.2453650719
# Std. Error: 64.439855517
#
# For bursts @ [ 120.   157.5]
# Avg offset: 86.6972695454
# Std. Error: 58.8663182606
#
# For bursts @ [ 120.  180.]
# Avg offset: 112.417721768
# Std. Error: 50.6866248319
#
# For bursts @ [ 120.   202.5]
# Avg offset: 108.885100722
# Std. Error: 62.0034004862
#
# For bursts @ [ 120.  225.]
# Avg offset: 110.394070678
# Std. Error: 49.6686887545
#
# For bursts @ [ 120.   247.5]
# Avg offset: 95.4558766324
# Std. Error: 53.8592876732
#
# For bursts @ [ 120.  270.]
# Avg offset: 102.312252668
# Std. Error: 52.4918594542
#
# For bursts @ [ 120.   292.5]
# Avg offset: 115.589862317
# Std. Error: 36.5520435693
#
# For bursts @ [ 120.  315.]
# Avg offset: 109.700045222
# Std. Error: 41.1854630737
#
# For bursts @ [ 120.   337.5]
# Avg offset: 104.257764169
# Std. Error: 61.2770062356
#
# For bursts @ [ 131.8103149   11.25     ]
# Avg offset: 120.117740903
# Std. Error: 38.1200648396
#
# For bursts @ [ 131.8103149   33.75     ]
# Avg offset: 113.231771071
# Std. Error: 47.5229071461
#
# For bursts @ [ 131.8103149   56.25     ]
# Avg offset: 125.815850836
# Std. Error: 42.1442137787
#
# For bursts @ [ 131.8103149   78.75     ]
# Avg offset: 109.438921896
# Std. Error: 51.634230783
#
# For bursts @ [ 131.8103149  101.25     ]
# Avg offset: 114.556403376
# Std. Error: 39.075625887
#
# For bursts @ [ 131.8103149  123.75     ]
# Avg offset: 123.283894553
# Std. Error: 31.6258533914
#
# For bursts @ [ 131.8103149  146.25     ]
# Avg offset: 114.025873452
# Std. Error: 45.3292055957
#
# For bursts @ [ 131.8103149  168.75     ]
# Avg offset: 126.374180687
# Std. Error: 50.5695325238
#
# For bursts @ [ 131.8103149  191.25     ]
# Avg offset: 106.719346576
# Std. Error: 64.2568056962
#
# For bursts @ [ 131.8103149  213.75     ]
# Avg offset: 113.061168905
# Std. Error: 46.5420263641
#
# For bursts @ [ 131.8103149  236.25     ]
# Avg offset: 125.854775875
# Std. Error: 42.5959704816
#
# For bursts @ [ 131.8103149  258.75     ]
# Avg offset: 112.823357226
# Std. Error: 48.1869269957
#
# For bursts @ [ 131.8103149  281.25     ]
# Avg offset: 118.657817453
# Std. Error: 43.2397243807
#
# For bursts @ [ 131.8103149  303.75     ]
# Avg offset: 115.674397993
# Std. Error: 38.9922068669
#
# For bursts @ [ 131.8103149  326.25     ]
# Avg offset: 116.82002616
# Std. Error: 63.9767968173
#
# For bursts @ [ 131.8103149  348.75     ]
# Avg offset: 116.315530923
# Std. Error: 31.9519571138
#
# For bursts @ [ 144.3409123   15.       ]
# Avg offset: 113.31248426
# Std. Error: 47.8045524155
#
# For bursts @ [ 144.3409123   45.       ]
# Avg offset: 105.775311297
# Std. Error: 59.1345336378
#
# For bursts @ [ 144.3409123   75.       ]
# Avg offset: 113.54059617
# Std. Error: 53.4702963744
#
# For bursts @ [ 144.3409123  105.       ]
# Avg offset: 112.415814022
# Std. Error: 54.1989978524
#
# For bursts @ [ 144.3409123  135.       ]
# Avg offset: 118.447616554
# Std. Error: 38.4269120779
#
# For bursts @ [ 144.3409123  165.       ]
# Avg offset: 118.85985081
# Std. Error: 40.8628340975
#
# For bursts @ [ 144.3409123  195.       ]
# Avg offset: 134.800742408
# Std. Error: 39.8786018334
#
# For bursts @ [ 144.3409123  225.       ]
# Avg offset: 117.612700892
# Std. Error: 41.9082783295
#
# For bursts @ [ 144.3409123  255.       ]
# Avg offset: 121.478556374
# Std. Error: 44.5348245474
#
# For bursts @ [ 144.3409123  285.       ]
# Avg offset: 125.184611369
# Std. Error: 42.667958361
#
# For bursts @ [ 144.3409123  315.       ]
# Avg offset: 129.961094207
# Std. Error: 33.4599644851
#
# For bursts @ [ 144.3409123  345.       ]
# Avg offset: 104.807405158
# Std. Error: 55.0672495199
#
# For bursts @ [ 156.44353569   22.5       ]
# Avg offset: 127.055706193
# Std. Error: 53.3911407481
#
# For bursts @ [ 156.44353569   67.5       ]
# Avg offset: 124.148486762
# Std. Error: 56.1629218389
#
# For bursts @ [ 156.44353569  112.5       ]
# Avg offset: 123.702106916
# Std. Error: 48.1820321631
#
# For bursts @ [ 156.44353569  157.5       ]
# Avg offset: 125.16236654
# Std. Error: 50.1398677561
#
# For bursts @ [ 156.44353569  202.5       ]
# Avg offset: 120.984531252
# Std. Error: 49.7394980149
#
# For bursts @ [ 156.44353569  247.5       ]
# Avg offset: 119.346029982
# Std. Error: 59.1557000246
#
# For bursts @ [ 156.44353569  292.5       ]
# Avg offset: 131.684782798
# Std. Error: 47.080182184
#
# For bursts @ [ 156.44353569  337.5       ]
# Avg offset: 124.404217039
# Std. Error: 44.6857484612
#
# For bursts @ [ 168.28414761   45.        ]
# Avg offset: 129.250733273
# Std. Error: 51.9011342494
#
# For bursts @ [ 168.28414761  135.        ]
# Avg offset: 142.857357518
# Std. Error: 37.5967221541
#
# For bursts @ [ 168.28414761  225.        ]
# Avg offset: 128.200870341
# Std. Error: 48.2438815789
#
# For bursts @ [ 168.28414761  315.        ]
# Avg offset: 119.838128368
# Std. Error: 57.3323911792
# /Users/noahkasmanoff/anaconda/lib/python3.6/site-packages/healpy/newvisufunc.py:111: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   washold = ax.ishold()
# /Users/noahkasmanoff/anaconda/lib/python3.6/site-packages/healpy/newvisufunc.py:167: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(washold)
